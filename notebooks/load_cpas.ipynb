# %%
import re

import pandas
import s3fs
import sqlalchemy

import cpas_reports

# %% [markdown]
# ## Collating CPAS Reports

# %% [markdown]
# The CPAS web portal has a few pre-canned reports. We have copied those,
# and placed them in `cpas_reports.py`.
#
# The following collates those reports for all the grant years,
# and uploads them to S3 as parquet files.
#
# These should be considered views onto the underlying tables,
# but are a convenient entry point into the CPAS database.

# %%
def combine_reports(callable, min_year, max_year):
    combined = pandas.DataFrame()
    for year in range(min_year, max_year + 1):
        try:
            df = cpas_reports.get_pep_info(year)
            combined = pandas.concat([combined, df], axis=0, sort=False)
        except sqlalchemy.exc.DatabaseError as e:
            print(f"Failed to load year {year} with message {str(e)[:89]}")
    return combined.reset_index(drop=True)

# %%
MIN_YEAR = 30
MAX_YEAR = 46

pep_info = combine_reports(cpas_reports.get_pep_info, MIN_YEAR, MAX_YEAR)
application_info = combine_reports(cpas_reports.get_application_info, MIN_YEAR, MAX_YEAR)
application_list = combine_reports(cpas_reports.app_list, MIN_YEAR, MAX_YEAR)
grnt_gpr = combine_reports(cpas_reports.get_grnt_gpr, MIN_YEAR, MAX_YEAR)
# Out:
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: "\n \tSELECT \n\t

# %%
BUCKET = "s3://hcid-cdbg-project-ita-data"
pep_info.to_parquet(f"{BUCKET}/pep-info.parquet")
application_info.to_parquet(f"{BUCKET}/application_info.parquet")
application_list.to_parquet(f"{BUCKET}/application_list.parquet")
grnt_gpr.to_parquet(f"{BUCKET}/grant_gpr.parquet")

# %% [markdown]
# ## Where is the data in CPAS?
#
# The block grant data seems to be mostly organized by grant year in schemas/users titled "`GRNT{year}`".
# Each of those schemas has a large number of tables, which are similar, but not identical from year to year.
# Let's get some descriptive statistics of all of the tables.

# %%
engine = cpas_reports.engine
schemas = sqlalchemy.inspect(engine).get_schema_names()
# Get all the schemas starting with `grnt`, indicating a single grant year.
schemas = [s for s in schemas if re.match("grnt\d+", s)]
schemas
# Out:
# ['grnt30',
#  'grnt31',
#  'grnt32',
#  'grnt33',
#  'grnt34',
#  'grnt35',
#  'grnt36',
#  'grnt37',
#  'grnt38',
#  'grnt39',
#  'grnt40',
#  'grnt41',
#  'grnt42',
#  'grnt43',
#  'grnt44',
#  'grnt45',
#  'grnt46']

# %%
# Collect all the tables in each schema, as well as a counter dictionary
# to see how many times each table name appears across the schemas
counts = {}
data = {}
for schema in schemas:
    tables = engine.table_names(schema=schema)
    data[schema] = tables
    for t in tables:
        counts[t] = counts.get(t, 0) + 1

# %%
# Create a meta-table describing whether a given table appears in a schema
all_tables = set(counts.keys())
tables_df = pandas.DataFrame({key: [t in data[key] for t in all_tables] for key in data}, index=all_tables)
tables_df = tables_df.assign(count=pandas.Series(counts)).sort_values("count", ascending=False)

# %%
# Visualize which tables are in common in a given schema:
tables_df.style.applymap(lambda x: "color: green" if x == True else "color: red" if x == False else "")
# Out:
# <style  type="text/css" >
#     #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col0 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col1 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col2 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col3 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col4 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col5 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col6 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col7 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col8 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col9 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col10 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col11 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col12 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col13 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col14 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col15 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row0_col16 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col0 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col1 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col2 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col3 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col4 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col5 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col6 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col7 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col8 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col9 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col10 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col11 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col12 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col13 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col14 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col15 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row1_col16 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col0 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col1 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col2 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col3 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col4 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col5 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col6 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col7 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col8 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col9 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col10 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col11 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col12 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col13 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col14 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col15 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row2_col16 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col0 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col1 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col2 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col3 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col4 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col5 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col6 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col7 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col8 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col9 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col10 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col11 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col12 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col13 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col14 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col15 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row3_col16 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col0 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col1 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col2 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col3 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col4 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col5 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col6 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col7 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col8 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col9 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col10 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col11 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col12 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col13 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col14 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col15 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row4_col16 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row5_col0 {
#             color:  green;
#         }    #T_2a291fc0_c863_11ea_bd4d_bf63de9dd4b7row5_col1 {
#             color:  green;
#         }    #T_2a291fc0_c863_1

# %%
# All the tables which exist in every grant year since 39
# This year is somewhat arbitrarily chosen,
# but it does correspond to the most commonly used tables in recent years.
common_tables = tables_df[tables_df[schemas[9:]].all(axis=1)].index
common_tables
# Out:
# Index(['grnt_src_fnd', 'grnt_aplctn_prog', 'grnt_aplctn_attchmnt',
#        'grnt_l_stat', 'grnt_l_note_typ', 'grnt_case_note', 'grnt_l_attchmnt',
#        'grnt_aplctn', 'grnt_l_aplc_readiness', 'grnt_bud', 'grnt_l_fnd',
#        'grnt_chk_list', 'grnt_prjct_accmplsh', 'grnt_stat', 'grnt_l_accmplsh',
#        'grnt_hud_objctive', 'grnt_l_recom_aprv', 'grnt_prr_yr_cdbg',
#        'grnt_accmplsh_dtl', 'grnt_form', 'grnt_cntct',
#        'serv_area_census_tract', 'grnt_loctn_typ', 'grnt_hud_cd',
#        'grnt_bud_expns', 'grnt_bud_gnrl_dtl', 'grnt_prjct_loctn',
#        'grnt_aplctn_note', 'grnt_l_expns', 'grnt_hstrcl_rvw',
#        'grnt_l_prjct_prty', 'grnt_cptl_typ', 'grnt_prjct_fnd',
#        'grnt_cptl_plan', 'grnt_l_aplc_elig', 'grnt_cptl_plan_dtl',
#        'grnt_pps_accmplsh', 'grnt_l_davis_bacon', 'grnt_pps_accmplsh_dtl',
#        'grnt_l_pep_note_typ', 'grnt_l_send_out_mthd', 'grnt_l_pep_stts',
#        'grnt_l_rec_color', 'grnt_pep_prjctd_reimb', 'grnt_l_proj_typ',
#        'grnt_pep_lvrg_resrc', 'grnt_l_proj_prity_mayor', 'grnt_l_objctive',
#        'grnt_pep', 'grnt_l_otcm', 'grnt_pep_milestones', 'grnt_l_pep_typ',
#        'grnt_pep_cncl_dist', 'grnt_l_sub_recip', 'grnt_pep_note',
#        'grnt_pps_addr', 'grnt_prpsd_proj', 'grnt_pep_accmplsh',
#        'grnt_l_cncl_dist', 'grnt_l_loc', 'grnt_l_otcm_catg', 'grnt_gpr',
#        'grnt_gpr_census_tract', 'grnt_gpr_duns', 'grnt_l_cbdo_color',
#        'grnt_cbdo_doc', 'grnt_l_job_catg', 'grnt_gpr_race', 'grnt_l_race',
#        'grnt_l_cbdo_doc', 'grnt_gpr_job_catg', 'grnt_l_incm_lvl', 'grnt_cbdo',
#        'grnt_l_cbdo_stts', 'grnt_l_gpr_actv_stts', 'grnt_l_proj_loc_rsn',
#        'grnt_gpr_incm_lvl', 'grnt_census_tract', 'grnt_l_env_ceqa_stts',
#        'grnt_pep_chk_list_photo', 'grnt_gpr_attchmnt', 'grnt_pep_chk_list',
#        'grnt_pep_attchmnt', 'grnt_l_photo_site', 'grnt_pep_chk_list_fund',
#        'grnt_prjct_fnd_amnd', 'grnt_pep_oth_fnd_src', 'grnt_chk_list_photo',
#        'grnt_pep_accs_auth', 'grnt_hist', 'grnt_sl_dept_cntct',
#        'grnt_chk_list_fund', 'grnt_l_accmplsh_catg', 'grnt_pep_goal_otcm',
#        'grnt_l_conplan_catg', 'grnt_aplc_conplan_catg',
#        'grnt_gpr_idis_actv_trkng', 'grnt_aplc_goal_otcm',
#        'grnt_aplc_prjct_pep_dept', 'grnt_goal_otcm'],
#       dtype='object')

# %%
def combine_grant_years(t, engine):
    combined = pandas.DataFrame()
    for year in range(MIN_YEAR, MAX_YEAR+1):
        try:
            df = pandas.read_sql(f"SELECT * FROM grnt{year}.{t}", engine)
            df = df.assign(year=year)
            combined = pandas.concat([combined, df], axis=0, sort=False)
        except sqlalchemy.exc.DatabaseError as e:
            print(f"Failed to load year {year} with message {str(e)[:89]}")
    return combined.reset_index(drop=True)

# %%
# Combine the common tables across grant years
database = {}
for t in common_tables:
    combined = combine_grant_years(t, engine)
    database[t] = combined
    print(f"Loaded {t}, with {len(combined)} records")
# Out:
# Loaded grnt_src_fnd, with 3339 records
# Loaded grnt_aplctn_prog, with 17761 records
# Loaded grnt_aplctn_attchmnt, with 5388 records
# Loaded grnt_l_stat, with 136 records
# Loaded grnt_l_note_typ, with 289 records
# Loaded grnt_case_note, with 4466 records
# Loaded grnt_l_attchmnt, with 97 records
# Loaded grnt_aplctn, with 3098 records
# Loaded grnt_l_aplc_readiness, with 68 records
# Loaded grnt_bud, with 3276 records
# Loaded grnt_l_fnd, with 83 records
# Loaded grnt_chk_list, with 2154 records
# Loaded grnt_prjct_accmplsh, with 4564 records
# Loaded grnt_stat, with 3095 records
# Loaded grnt_l_accmplsh, with 272 records
# Loaded grnt_hud_objctive, with 136 records
# Loaded grnt_l_recom_aprv, with 34 records
# Loaded grnt_prr_yr_cdbg, with 1867 records
# Loaded grnt_accmplsh_dtl, with 8824 records
# Loaded grnt_form, with 116 records
# Loaded grnt_cntct, with 6130 records
# Loaded serv_area_census_tract, with 13988 records
# Loaded grnt_loctn_typ, with 12 records
# Loaded grnt_hud_cd, with 1677 records
# Loaded grnt_bud_expns, with 11847 records
# Loaded grnt_bud_gnrl_dtl, with 6733 records
# Loaded grnt_prjct_loctn, with 4262 records
# Loaded grnt_aplctn_note, with 1662 records
# Loaded grnt_l_expns, with 289 records
# Loaded grnt_hstrcl_rvw, with 76 records
# Loaded grnt_l_prjct_prty, with 135 records
# Loaded grnt_cptl_typ, with 221 records
# Loaded grnt_prjct_fnd, with 4729 records
# Loaded grnt_cptl_plan, with 574 records
# Loaded grnt_l_aplc_elig, with 68 records
# Loaded grnt_cptl_plan_dtl, with 12774 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pps_accmplsh, with 1702 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_davis_bacon, with 50 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pps_accmplsh_dtl, with 1710 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_pep_note_typ, with 204 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_send_out_mthd, with 45 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_pep_stts, with 59 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_rec_color, with 60 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_prjctd_reimb, with 5958 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_proj_typ, with 141 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_lvrg_resrc, with 1343 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_proj_prity_mayor, with 90 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_objctive, with 45 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep, with 2832 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_otcm, with 45 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_milestones, with 0 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_pep_typ, with 60 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_cncl_dist, with 3325 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_sub_recip, with 90 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_note, with 18727 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pps_addr, with 1932 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_prpsd_proj, with 1023 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_accmplsh, with 3410 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_cncl_dist, with 225 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_loc, with 75 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_otcm_catg, with 643 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr, with 4078 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr_census_tract, with 4708 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr_duns, with 196 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_cbdo_color, with 36 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_cbdo_doc, with 1247 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_job_catg, with 108 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr_race, with 11055 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_race, with 120 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_cbdo_doc, with 72 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr_job_catg, with 1578 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_incm_lvl, with 48 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_cbdo, with 231 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_cbdo_stts, with 24 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_gpr_actv_stts, with 36 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_proj_loc_rsn, with 48 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr_incm_lvl, with 5086 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_census_tract, with 20192 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_env_ceqa_stts, with 60 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_chk_list_photo, with 982 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr_attchmnt, with 227 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_chk_list, with 1488 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_attchmnt, with 7215 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_photo_site, with 100 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_chk_list_fund, with 2 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_prjct_fnd_amnd, with 156 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_oth_fnd_src, with 1256 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_chk_list_photo, with 726 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_accs_auth, with 1801 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_hist, with 7377 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_sl_dept_cntct, with 601 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_chk_list_fund, with 0 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_accmplsh_catg, with 56 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_pep_goal_otcm, with 1243 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_l_conplan_catg, with 40 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_aplc_conplan_catg, with 1082 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_gpr_idis_actv_trkng, with 0 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_aplc_goal_otcm, with 1294 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_aplc_prjct_pep_dept, with 9 records
# Failed to load year 30 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 31 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 32 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 33 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 34 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 35 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 36 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 37 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Failed to load year 38 with message (cx_Oracle.DatabaseError) ORA-00942: table or view does not exist [SQL: 'SELECT * FROM gr
# Loaded grnt_goal_otcm, with 184 records

# %%
# Drop tables if they start with "grnt_l_", as HCID indicates that those are not important,
# as well as tables that have fewer than 100 records, hopefully indicating that they
# are less-used
relevant_tables = {k for k,v in database.items() if not k.startswith("grnt_l_") and len(v) > 100}
database = {k: v for k,v in database.items() if k in relevant_tables}

# %%
# Create a sqlite database with the collated grant tables.

cpas = sqlalchemy.create_engine("sqlite:///cpas.sqlite")

for key, table in database.items():
    print(f"Writing {key}")
    # Attempt to fix broken datetimes
    coerce_dt = [
        c for c in table.columns
        if pandas.core.indexes.accessors.is_datetime_arraylike(table[c])
    ]
    table = table.assign(**{c: pandas.to_datetime(table[c].fillna(pandas.NaT), errors="coerce") for c in coerce_dt})
    # Write to SQLite
    table.to_sql(key, cpas, index=False, if_exists="replace")
# Out:
# Writing grnt_src_fnd
# Writing grnt_aplctn_prog
# Writing grnt_aplctn_attchmnt
# Writing grnt_case_note
# Writing grnt_aplctn
# Writing grnt_bud
# Writing grnt_chk_list
# Writing grnt_prjct_accmplsh
# Writing grnt_stat
# Writing grnt_hud_objctive
# Writing grnt_prr_yr_cdbg
# Writing grnt_accmplsh_dtl
# Writing grnt_form
# Writing grnt_cntct
# Writing serv_area_census_tract
# Writing grnt_hud_cd
# Writing grnt_bud_expns
# Writing grnt_bud_gnrl_dtl
# Writing grnt_prjct_loctn
# Writing grnt_aplctn_note
# Writing grnt_cptl_typ
# Writing grnt_prjct_fnd
# Writing grnt_cptl_plan
# Writing grnt_cptl_plan_dtl
# Writing grnt_pps_accmplsh
# Writing grnt_pps_accmplsh_dtl
# Writing grnt_pep_prjctd_reimb
# Writing grnt_pep_lvrg_resrc
# Writing grnt_pep
# Writing grnt_pep_cncl_dist
# Writing grnt_pep_note
# Writing grnt_pps_addr
# Writing grnt_prpsd_proj
# Writing grnt_pep_accmplsh
# Writing grnt_gpr
# Writing grnt_gpr_census_tract
# Writing grnt_gpr_duns
# Writing grnt_cbdo_doc
# Writing grnt_gpr_race
# Writing grnt_gpr_job_catg
# Writing grnt_cbdo
# Writing grnt_gpr_incm_lvl
# Writing grnt_census_tract
# Writing grnt_pep_chk_list_photo
# Writing grnt_gpr_attchmnt
# Writing grnt_pep_chk_list
# Writing grnt_pep_attchmnt
# Writing grnt_prjct_fnd_amnd
# Writing grnt_pep_oth_fnd_src
# Writing grnt_chk_list_photo
# Writing grnt_pep_accs_auth
# Writing grnt_hist
# Writing grnt_sl_dept_cntct
# Writing grnt_pep_goal_otcm
# Writing grnt_aplc_conplan_catg
# Writing grnt_aplc_goal_otcm
# Writing grnt_goal_otcm

# %%
fs = s3fs.S3FileSystem()
fs.upload("./cpas.sqlite", f"{BUCKET}/cpas.sqlite")
