# %% [markdown]
# # Get the raw Census data into shape
# * move to script when ready
# * [Census GEOIDs](https://www.census.gov/programs-surveys/geography/guidance/geo-identifiers.html)

# %%
import numpy as np
import pandas as pd
import intake
import os
import geopandas as gpd
import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-46e406610476> in <module>
#       4 import os
#       5 import geopandas as gpd
# ----> 6 import utils
#
# ModuleNotFoundError: No module named 'utils'

# %%
catalog = intake.open_catalog('../catalogs/*.yml')

# %%
df = pd.read_csv('../data/Census/population_tract.csv')
df = df[df.tract==143700]

# %%
# Create GEOID, but make sure it comes out to 11 characters
for col in ['state', 'county', 'tract']:
    df[col] = df[col].astype(str)

df.state = df.state.str.zfill(width = 2)
df.county = df.county.str.zfill(width = 3)

df['GEOID'] = df.state + df.county + df.tract

# %%
# Create list where the columns with "_" at some place in the column name are selected.
oldcols = [x for x in df.columns if x.find('_') > 0]

# Create dictionary where old column names get renamed starting from the character "_" to the end
newcols = {x: x[x.find('_') + 1: ] for x in oldcols}

# %%
df.rename(columns = newcols, inplace = True)

# %%
drop_me = ['state', 'county', 'tract', 'NAME']
df = df.drop(columns = drop_me)

df
